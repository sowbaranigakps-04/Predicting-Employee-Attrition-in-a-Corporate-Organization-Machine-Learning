# %% [markdown]
# <a href="https://colab.research.google.com/github/sowbaranigakps-04/Predicting-Employee-Attrition-in-a-Corporate-Organization-Machine-Learning/blob/main/Employee_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/employee_attrition_dataset.csv')

# %%
df
# Out:
#       EmployeeID  Age  Gender MaritalStatus    Education Department  \
# 0              1   54    Male        Single          PhD      Sales
# 1              2   47    Male       Married       Master    Finance
# 2              3   41  Female       Married       Master      Sales
# 3              4   29    Male      Divorced  High School         IT
# 4              5   37  Female      Divorced  High School         IT
# ...          ...  ...     ...           ...          ...        ...
# 4995        4996   60    Male       Married     Bachelor    Finance
# 4996        4997   29    Male      Divorced  High School    Finance
# 4997        4998   37    Male      Divorced          PhD         IT
# 4998        4999   38    Male       Married     Bachelor         IT
# 4999        5000   26    Male        Single  High School        R&D
#
#               JobRole  YearsAtCompany  YearsInCurrentRole  MonthlyIncome  \
# 0             Analyst              17                  12       19618.16
# ...

# %%
df.drop('EmployeeID',axis=1,inplace=True)
df.drop('Education',axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender MaritalStatus Department          JobRole  YearsAtCompany  \
# 0      54    Male        Single      Sales          Analyst              17
# 1      47    Male       Married    Finance       Technician              32
# 2      41  Female       Married      Sales          Manager              37
# 3      29    Male      Divorced         IT          Manager               3
# 4      37  Female      Divorced         IT        Developer              25
# ...   ...     ...           ...        ...              ...             ...
# 4995   60    Male       Married    Finance          Analyst              12
# 4996   29    Male      Divorced    Finance        Developer              23
# 4997   37    Male      Divorced         IT  Sales Executive              28
# 4998   38    Male       Married         IT  Sales Executive              12
# 4999   26    Male        Single        R&D  Sales Executive               2
#
# ...

# %%
df.isnull().any()
# Out:
# Age                      False
# Gender                   False
# MaritalStatus            False
# Department               False
# JobRole                  False
# YearsAtCompany           False
# YearsInCurrentRole       False
# MonthlyIncome            False
# JobSatisfaction          False
# WorkLifeBalance          False
# TrainingTimesLastYear    False
# OverTime                 False
# DistanceFromHome         False
# Attrition                False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.Gender=le.fit_transform(df.Gender)
df.MaritalStatus=le.fit_transform(df.MaritalStatus)
df.Department=le.fit_transform(df.Department)
df.JobRole=le.fit_transform(df.JobRole)
df.OverTime=le.fit_transform(df.OverTime)

# %%
df.Attrition=le.fit_transform(df.Attrition)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
ats=['Age','MonthlyIncome', 'DistanceFromHome']
min_max_scaler = MinMaxScaler()
df[ats] = min_max_scaler.fit_transform(df[ats])

# %%
df
# Out:
#            Age  Gender  MaritalStatus  Department  JobRole  YearsAtCompany  \
# 0     0.761905       1              2           4        0              17
# 1     0.595238       1              1           0        4              32
# 2     0.452381       0              1           4        2              37
# 3     0.166667       1              0           2        2               3
# 4     0.357143       0              0           2        1              25
# ...        ...     ...            ...         ...      ...             ...
# 4995  0.904762       1              1           0        0              12
# 4996  0.166667       1              0           0        1              23
# 4997  0.357143       1              0           2        3              28
# 4998  0.380952       1              1           2        3              12
# 4999  0.095238       1              2           3        3               2
#
# ...

# %%
df.YearsAtCompany.max()
# Out:
# 39

# %%
X=df.iloc[:,:14]
y=df.iloc[:,-1]
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 4995    1
# 4996    0
# 4997    0
# 4998    0
# 4999    1
# Name: Attrition, Length: 5000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 25,random_state = 46)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
acc_knn = round(accuracy_score(y_pred,y_test), 2) * 100
print("Accuracy :" ,acc_knn)
# Out:
# Accuracy : 60.0

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb = XGBClassifier().fit(X_train, y_train)
y_pred = xgb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Accuracy: 100.0%
